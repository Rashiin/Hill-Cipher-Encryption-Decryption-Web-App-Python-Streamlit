# %%
# !pip install streamlit numpy sympy
# Out:
# Collecting streamlit
#   Downloading streamlit-1.42.2-py2.py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: numpy in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (1.26.4)
# Requirement already satisfied: sympy in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (1.10.1)
# Requirement already satisfied: altair<6,>=4.0 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (5.1.2)
# Collecting blinker<2,>=1.0.0 (from streamlit)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (4.2.2)
# Requirement already satisfied: click<9,>=7.0 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (7.0)
# Requirement already satisfied: packaging<25,>=20 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (21.3)
# Requirement already satisfied: pandas<3,>=1.4.0 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (3.20.3)
# Collecting pyarrow>=7.0 (from streamlit)
#   Downloading pyarrow-19.0.1-cp39-cp39-macosx_12_0_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: requests<3,>=2.27 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (13.6.0)
# Collecting tenacity<10,>=8.1.0 (from streamlit)
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (4.8.0)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (6.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from sympy) (1.2.1)
# Requirement already satisfied: jinja2 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit) (2.11.3)
# Requirement already satisfied: jsonschema>=3.0 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit) (4.4.0)
# Requirement already satisfied: toolz in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit) (0.11.2)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from packaging<25,>=20->streamlit) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from pandas<3,>=1.4.0->streamlit) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from pandas<3,>=1.4.0->streamlit) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (2021.10.8)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from rich<14,>=10.14.0->streamlit) (2.16.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.0.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.42.2-py2.py3-none-any.whl (9.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 113.9 kB/s eta 0:00:0000:0200:04
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
# Downloading pyarrow-19.0.1-cp39-cp39-macosx_12_0_x86_64.whl (32.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.1/32.1 MB 153.7 kB/s eta 0:00:0000:0100:07
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 151.7 kB/s eta 0:00:0000:0100:03
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: tenacity, smmap, pyarrow, blinker, pydeck, gitdb, gitpython, streamlit
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.0.1
#     Uninstalling tenacity-8.0.1:
#       Successfully uninstalled tenacity-8.0.1
# Successfully installed blinker-1.9.0 gitdb-4.0.12 gitpython-3.1.44 pyarrow-19.0.1 pydeck-0.9.1 smmap-5.0.2 streamlit-1.42.2 tenacity-9.0.0
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import streamlit as st
import numpy as np
from sympy import Matrix

# تبدیل متن به بردار عددی
def text_to_vector(text):
    return [ord(char) - ord('A') for char in text]

# تبدیل بردار عددی به متن
def vector_to_text(vector):
    return ''.join(chr(int(num) + ord('A')) for num in vector)

# رمزگذاری با Hill Cipher
def encrypt_hill(plaintext, key_matrix):
    n = len(key_matrix)
    while len(plaintext) % n != 0:
        plaintext += 'X'  # اضافه کردن حروف تصادفی (Padding)

    plaintext_vector = np.array(text_to_vector(plaintext.upper())).reshape(-1, n).T
    encrypted_vector = np.mod(np.dot(key_matrix, plaintext_vector), 26)
    
    return vector_to_text(encrypted_vector.T.flatten())

# رمزگشایی با Hill Cipher
def decrypt_hill(ciphertext, key_matrix):
    n = len(key_matrix)
    ciphertext_vector = np.array(text_to_vector(ciphertext.upper())).reshape(-1, n).T
    
    try:
        key_matrix_inv = Matrix(key_matrix).inv_mod(26)
        key_matrix_inv = np.array(key_matrix_inv).astype(int)
    except ValueError:
        return "ماتریس کلید معکوس‌پذیر نیست!"

    decrypted_vector = np.mod(np.dot(key_matrix_inv, ciphertext_vector), 26)
    
    return vector_to_text(decrypted_vector.T.flatten())

# ---- UI در Streamlit ----
st.title("🔐 رمزنگاری و رمزگشایی متن با Hill Cipher")

# انتخاب ماتریس کلید (ثابت یا ورودی کاربر)
st.sidebar.header("⚙ تنظیمات کلید")
key_option = st.sidebar.selectbox("نوع کلید", ["پیش‌فرض (۲×۲)", "ورودی دستی"])

if key_option == "پیش‌فرض (۲×۲)":
    key_matrix = np.array([[3, 3], [2, 5]])  # کلید ثابت
else:
    key_matrix = np.zeros((2, 2), dtype=int)
    for i in range(2):
        for j in range(2):
            key_matrix[i, j] = st.sidebar.number_input(f"عنصر [{i+1},{j+1}]:", min_value=0, max_value=25, step=1)

st.sidebar.write("🔑 **ماتریس کلید:**")
st.sidebar.write(key_matrix)

# ورودی کاربر برای متن اصلی
plaintext = st.text_input("📝 متن اصلی (Plaintext):")
if st.button("🔒 رمزگذاری"):
    if plaintext.isalpha():
        ciphertext = encrypt_hill(plaintext, key_matrix)
        st.success(f"🔑 متن رمزگذاری شده: {ciphertext}")
    else:
        st.error("لطفاً فقط حروف انگلیسی وارد کنید.")

# ورودی کاربر برای متن رمزگذاری‌شده
ciphertext_input = st.text_input("🔐 متن رمزگذاری‌شده (Ciphertext):")
if st.button("🔓 رمزگشایی"):
    if ciphertext_input.isalpha():
        decrypted_text = decrypt_hill(ciphertext_input, key_matrix)
        st.success(f"📝 متن رمزگشایی شده: {decrypted_text}")
    else:
        st.error("لطفاً فقط حروف انگلیسی وارد کنید.")

st.markdown("---")
st.markdown("🛠 **پروژه‌ای برای ترکیب جبر خطی و رمزنگاری** | توسعه‌یافته با ❤️ در Python")
# Out:
# 2025-03-01 23:59:59.208 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-01 23:59:59.415
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-03-01 23:59:59.415 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-01 23:59:59.416 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-01 23:59:59.416 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-01 23:59:59.416 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-01 23:59:59.416 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-01 23:59:59.417 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-01 23:59:59.417 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-01 23:59:59.417 Session state does not function when running a script without `streamlit run`
# 2025-03-01 23:59:59.418 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-01 23:59:59.418 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-01 23:59:59.418 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-01 23:59:59.419 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-01 23:59:59.419 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-01 23:59:59.419 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# /Users/rashinfarahani/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (
# 2025-03-02 00:00:09.019 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-02 00:00:09.020 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-02 00:00:09.021 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-02 00:00:09.021 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-02 00:00:09.021 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-02 00:00:09.021 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-02 00:00:09.022 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-02 00:00:09.022 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-02 00:00:09.022 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-02 00:00:09.022 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-02 00:00:09.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-02 00:00:09.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-02 00:00:09.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-02 00:00:09.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-02 00:00:09.024 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-02 00:00:09.024 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-02 00:00:09.024 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-02 00:00:09.024 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-02 00:00:09.025 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-02 00:00:09.025 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-02 00:00:09.025 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-02 00:00:09.025 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-02 00:00:09.025 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-02 00:00:09.026 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-02 00:00:09.026 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-02 00:00:09.026 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-02 00:00:09.027 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-02 00:00:09.027 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
